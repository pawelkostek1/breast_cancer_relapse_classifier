# %% [markdown]
# # Breast cancer relapse classification

# %% [markdown]
# In this IPython notebook we folmulate breast cancer relapse prediction as a classification problem. We use the PFSNet based scores to construct features for the classfier. We then perform predictions of the cancer relapses.

# %%
#Import common Python modules
import numpy as np
import scipy as sp
import matplotlib as plot
import Bio
import pandas as pd

# %matplotlib inline

# %%
#Load the datasets into pandas dataframes.
dataset_column = open("datasets/breast_cancer_dataset_columns.txt","r")
dataset = pd.read_csv('datasets/breast_cancer_dataset.txt', delimiter='\t', usecols=dataset_column.read().split('\t'))
relapse_dataset = pd.read_csv('datasets/relapse_info.txt', delimiter='\t')
id_conversion = pd.read_csv('id_conversion_data.txt', delimiter='\t')

# %% [markdown]
# ## 1. Initial data preprocessing

# %%
#Create a file with all the affymetrix gene names
f = open("affymetrix_genes.txt","w+")
for index in dataset.index:
    f.write(str(index)+"\n")
f.close()

# %%
#Create a file with the standard gene names. Unfortunatelly, using online tool it was not possible to resolve all the names.
g = open("gene_id.txt", "w+")
gene_names = []
for gene_name in id_conversion['Gene Name']:
    gene = gene_name.split(' ')[-1].split('(')[-1][:-1]
    gene_names.append(gene)
    g.write(str(gene)+"\n")
g.close()

# %%
# Create a gene correspondens table
affymetrix_gene_conversion_table = {}
for gene_id in id_conversion['ID']:
    for g_id in gene_id.split(','):
        affymetrix_gene_conversion_table[g_id] = str(id_conversion[id_conversion['ID'] == gene_id]['Gene Name'].values[0].split(' ')[-1].split('(')[-1][:-1])

# %%
#Using current method it was not possible to find gene names for most of the elements. 
#Therefore, we decide to use an alternative approach.
i = 1
for index in dataset.index:
    if index in affymetrix_gene_conversion_table.keys():
        print(str(i) +". "+ str(index)+": "+str(affymetrix_gene_conversion_table[index]))
        i = i + 1
    else:
        print("Failed to find the corresponding gene name.")
# Out:
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 1. 1438_at: EPHB3
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 2. 1773_at: CHURC1-FNTB
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 3. 1861_at: BAD
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 4. 200008_s_at: GDI2
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 5. 200011_s_at: ARF3
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 6. 200019_s_at: FAU
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 7. 200035_at: CTDNEP1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 8. 200040_at: KHDRBS1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 9. 200045_at: ABCF1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 10. 200056_s_at: C1D
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 11. 200066_at: IK
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 12. 200078_s_at: ATP6V0B
# Failed to find the corresponding gene name.
# 13. 200080_s_at: H3F3A
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 14. 200618_at: LASP1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 15. 200632_s_at: NDRG1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 16. 200644_at: MARCKSL1
# 17. 200645_at: GABARAP
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 18. 200663_at: CD63
# 19. 200664_s_at: DNAJB1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 20. 200675_at: CD81
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 21. 200700_s_at: KDELR2
# Failed to find the corresponding gene name.
# 22. 200702_s_at: DDX24
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 23. 200721_s_at: ACTR1A
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 24. 200729_s_at: ACTR2
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 25. 200744_s_at: GNB1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 26. 200760_s_at: ARL6IP5
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 27. 200784_s_at: LRP1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 28. 200837_at: BCAP31
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 29. 200851_s_at: IST1
# 30. 200852_x_at: GNB2
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 31. 200860_s_at: CNOT1
# Failed to find the corresponding gene name.
# 32. 200862_at: DHCR24
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 33. 200880_at: DNAJA1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 34. 200894_s_at: FKBP4
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 35. 200921_s_at: BTG1
# 36. 200922_at: KDELR1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 37. 200934_at: DEK
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 38. 200954_at: ATP6V0C
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 39. 200984_s_at: CD59
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 40. 201005_at: CD9
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 41. 201029_s_at: CD99
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 42. 201040_at: GNAI2
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 43. 201089_at: ATP6V1B2
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 44. 201097_s_at: ARF4
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 45. 201101_s_at: BCLAF1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 46. 201115_at: POLD2
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 47. 201128_s_at: ACLY
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 48. 201145_at: HAX1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 49. 201157_s_at: NMT1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 50. 201178_at: FBXO7
# Failed to find the corresponding gene name.
# 51. 201180_s_at: GNAI3
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 52. 201185_at: HTRA1
# 53. 201186_at: LRPAP1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 54. 201218_at: CTBP2
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 55. 201227_s_at: NDUFB8
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 56. 201236_s_at: BTG2
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 57. 201241_at: DDX1
# Failed to find the corresponding gene name.
# 58. 201243_s_at: ATP1B1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 59. 201253_s_at: CDIPT
# Failed to find the corresponding gene name.
# 60. 201255_x_at: BAG6
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 61. 201280_s_at: DAB2
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 62. 201298_s_at: MOB1A
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 63. 201304_at: NDUFA5
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 64. 201322_at: ATP5B
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 65. 201328_at: ETS2
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 66. 201383_s_at: NBR1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 67. 201386_s_at: DHX15
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 68. 201405_s_at: COPS6
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 69. 201412_at: LRP10
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 70. 201419_at: BAP1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 71. 201422_at: IFI30
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 72. 201440_at: DDX23
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 73. 201443_s_at: ATP6AP2
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 74. 201457_x_at: BUB3
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 75. 201464_x_at: JUN
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 76. 201467_s_at: NQO1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 77. 201473_at: JUNB
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 78. 201502_s_at: NFKBIA
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 79. 201510_at: ELF3
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 80. 201514_s_at: G3BP1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 81. 201520_s_at: GRSF1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 82. 201526_at: ARF5
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 83. 201544_x_at: BCL2L2-PABPN1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 84. 201579_at: FAT1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 85. 201584_s_at: DDX39A
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# ...
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 1991. 38447_at: GRK2
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 1992. 38707_r_at: E2F4
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 1993. 39817_s_at: DNPH1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 1994. 40255_at: DDX28
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 1995. 40850_at: FKBP8
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 1996. 44822_s_at: MIER2
# Failed to find the corresponding gene name.
# 1997. 45297_at: EHD2
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 1998. 45633_at: GINS3
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 1999. 45828_at: ATP5SL
# Failed to find the corresponding gene name.
# 2000. 46167_at: MROH7-TTC4
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 2001. 48580_at: CXXC1
# 2002. 48612_at: N4BP1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 2003. 52159_at: HEMK1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 2004. 54037_at: HPS4
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 2005. 58916_at: NDUFC2-KCTD14
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 2006. 64942_at: GPR153
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 2007. 66053_at: HNRNPUL2-BSCL2
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 2008. 76897_s_at: FKBP15
# Failed to find the corresponding gene name.
# 2009. 78047_s_at: MMP24-AS1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 2010. 823_at: CX3CL1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 2011. 90265_at: ADAP1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# 2012. 91703_at: EHBP1L1
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.
# Failed to find the corresponding gene name.

# %% [markdown]
# ### Gene name matching

# %% [markdown]
# Using the POST request we can query online database to retrieve the corresponding gene names. The code below show an example of retrieving gene name for a particular gene ids. The complete version of the gene names matching was implemented in a separate IPython notebook as due to nature of the method the time to retrieve all the correspondences is long.

# %%
#Load necessary libraries
import requests
import json

# %%
headers = {'content-type': 'application/x-www-form-urlencoded'}
#params = 'q=reporter:204252_at'
params = 'q=1017,1018,reporter:204252_at&fields=name,symbol'
res = requests.post('http://mygene.info/v3/query', data=params, headers=headers)
response = json.loads(res.content)
print(response)
# Out:
# [{'query': '1017', '_id': '1017', '_score': 1.55, 'name': 'cyclin dependent kinase 2', 'symbol': 'CDK2'}, {'query': '1018', '_id': '1018', '_score': 1.55, 'name': 'cyclin dependent kinase 3', 'symbol': 'CDK3'}, {'query': 'reporter:204252_at', 'notfound': True}]

# %%
#Load the conversion table between affymetrix and common gene names
conversion_table = pd.read_csv('datasets/conversion_table.txt', delimiter='\t')

# %%
conversion_table
# Out:
#           id             affymetrix_id               gene_name
# 0          0                 1007_s_at                    DDR1
# 1          1                   1053_at                    RFC2
# 2          2                    117_at                   HSPA6
# 3          3                    121_at                    PAX8
# 4          4                 1255_g_at                  GUCA1A
# 5          5                   1294_at                 MIR5193
# 6          6                   1316_at                    THRA
# 7          7                   1320_at                  PTPN21
# 8          8                 1405_i_at                    CCL5
# 9          9                   1431_at                  CYP2E1
# 10        10                   1438_at                   EPHB3
# 11        11                   1487_at                   ESRRA
# 12        12                 1494_f_at                  CYP2A6
# 13        13                 1598_g_at                    GAS6
# 14        14                 160020_at                   MMP14
# 15        15                   1729_at                   TRADD
# 16        16                   1773_at             CHURC1-FNTB
# 17        17                    177_at                    PLD1
# 18        18                    179_at  DTX2P1-UPK3BP1-PMS2P11
# 19        19                   1861_at                     BAD
# 20        20               200000_s_at                   PRPF8
# 21        21                 200001_at                  CAPNS1
# 22        22                 200002_at                   RPL35
# 23        23               200003_s_at                   RPL28
# 24        24                 200004_at                  EIF4G2
# 25        25                 200005_at                   EIF3D
# 26        26                 200006_at                   PARK7
# 27        27                 200007_at                   SRP14
# 28        28               200008_s_at                    GDI2
# 29        29                 200009_at                    GDI2
# ...      ...                       ...                     ...
# 22253  22253           AFFX-TrpnX-5_at                       -
# 22254  22254           AFFX-TrpnX-M_at                       -
# 22255  22255           AFFX-hum_alu_at                       -
# 22256  22256       AFFX-r2-Bs-dap-3_at                       -
# 22257  22257       AFFX-r2-Bs-dap-5_at                       -
# 22258  22258       AFFX-r2-Bs-dap-M_at                       -
# 22259  22259       AFFX-r2-Bs-lys-3_at                       -
# 22260  22260       AFFX-r2-Bs-lys-5_at                       -
# 22261  22261       AFFX-r2-Bs-lys-M_at                       -
# 22262  22262       AFFX-r2-Bs-phe-3_at                       -
# 22263  22263       AFFX-r2-Bs-phe-5_at                       -
# 22264  22264       AFFX-r2-Bs-phe-M_at                       -
# 22265  22265     AFFX-r2-Bs-thr-3_s_at                       -
# 22266  22266     AFFX-r2-Bs-thr-5_s_at                       -
# 22267  22267     AFFX-r2-Bs-thr-M_s_at                       -
# 22268  22268      AFFX-r2-Ec-bioB-3_at                       -
# 22269  22269      AFFX-r2-Ec-bioB-5_at                       -
# 22270  22270      AFFX-r2-Ec-bioB-M_at                       -
# 22271  22271      AFFX-r2-Ec-bioC-3_at                       -
# 22272  22272      AFFX-r2-Ec-bioC-5_at                       -
# 22273  22273      AFFX-r2-Ec-bioD-3_at                       -
# 22274  22274      AFFX-r2-Ec-bioD-5_at                       -
# 22275  22275  AFFX-r2-Hs18SrRNA-3_s_at                       -
# 22276  22276    AFFX-r2-Hs18SrRNA-5_at                       -
# 22277  22277  AFFX-r2-Hs18SrRNA-M_x_at                       -
# 22278  22278    AFFX-r2-Hs28SrRNA-3_at                       -
# 22279  22279    AFFX-r2-Hs28SrRNA-5_at                       -
# 22280  22280    AFFX-r2-Hs28SrRNA-M_at                       -
# 22281  22281       AFFX-r2-P1-cre-3_at                       -
# 22282  22282       AFFX-r2-P1-cre-5_at                       -
#
# [22283 rows x 3 columns]

# %% [markdown]
# ### Pathway retrieval

# %% [markdown]
# The code below is used to find pathways for a given gene. The pathways consists of genes that are interconnected. We create a list of all the pairs of genes that are connected in the pathway network and input them into a file. This is input data format necesary for the PFSNet.

# %%
#Load necessary libraries
from bioservices.kegg import KEGG
import progressbar
k = KEGG()

# %%
#This is the example of the code for finding a corresponding pathways for a given gene. 
#Then, for each pathway we find all the genes that constitute of the pathway (network).
#We write to a file a list of all the edges of all the pathway network for a given gene.
pathway = k.get_pathway_by_gene("CDK2", "hsa")
pfsnet_file = open("pfsnet_input_test.txt","w+")
for ind in pathway:
    print("************************************************")
    print(str(ind) +": "+str(pathway[ind]))
    print("************************************************")
    network = k.parse_kgml_pathway(ind)
    entries = pd.DataFrame.from_dict(network['entries'])
    for item in network['relations']:
        gene1 = entries[entries['id']==item['entry1']]
        gene2 = entries[entries['id']==item['entry2']]
        if gene1['gene_names'].values != None and gene2['gene_names'].values != None:
            gene1 = gene1['gene_names'].values[0].split(','[0])[0]
            gene2 = gene2['gene_names'].values[0].split(','[0])[0]
            pfsnet_file.write(str(pathway[ind]) +"\t"+ str(gene1)+"\t"+ str(gene2) + "\n")
            print(str(gene1) +" -> "+str(gene2)+"\n")
pfsnet_file.close()
# Out:
# ************************************************
# hsa04068: FoxO signaling pathway
# ************************************************
# TGFBR1 -> SMAD2
#
# SMAD4 -> SMAD2
#
# C00008 -> STK11
#
# C00020 -> STK11
#
# STK11 -> PRKAG2
#
# STK11 -> PRKAG2
#
# STK11 -> FOXO6...
#
# STK11 -> FOXO6...
#
# TGFB1 -> TGFBR1
#
# PRKAG2 -> FOXO6...
#
# PRKAG2 -> FOXO6...
#
# IGF1 -> IGF1R
#
# INS -> INSR
#
# IGF1R -> IRS1
#
# INSR -> IRS1
#
# IRS1 -> PIK3CA
#
# PIK3CA -> C05981
#
# C05981 -> PDPK1
#
# PDPK1 -> CHUK
#
# PDPK1 -> CHUK
#
# PDPK1 -> AKT3
#
# PDPK1 -> AKT3
#
# PDPK1 -> C8orf44-SGK3...
#
# PDPK1 -> C8orf44-SGK3...
#
# AKT3 -> CHUK
#
# AKT3 -> CHUK
#
# CHUK -> FOXO6...
#
# CHUK -> FOXO6...
#
# AKT3 -> FOXO6...
#
# AKT3 -> FOXO6...
#
# C8orf44-SGK3... -> FOXO6...
#
# C8orf44-SGK3... -> FOXO6...
#
# NLK -> FOXO6...
#
# NLK -> FOXO6...
#
# CDK2 -> FOXO6...
#
# CDK2 -> FOXO6...
#
# TPTEP2-CSNK1E -> FOXO6...
#
# TPTEP2-CSNK1E -> FOXO6...
#
# MAPK14 -> FOXO6...
#
# MAPK14 -> FOXO6...
#
# C00025 -> GRM1
#
# EGF -> EGFR
#
# EGFR -> GRB2
#
# GRB2 -> SOS1
#
# SOS1 -> HRAS
#
# HRAS -> ARAF
#
# ARAF -> MAP2K1
#
# ARAF -> MAP2K1
#
# MAP2K1 -> MAPK1
#
# MAP2K1 -> MAPK1
#
# MAPK8 -> FOXO6...
#
# MAPK8 -> FOXO6...
#
# STK4 -> FOXO6...
#
# STK4 -> FOXO6...
#
# CHUK -> PTEN
#
# PTEN -> C05981
#
# PTEN -> C05981
#
# FOXO6... -> CCNB3...
#
# FOXO6... -> CCND1
#
# FOXO6... -> CCNG2
#
# FOXO6... -> CDKN2B
#
# FOXO6... -> CDKN2D
#
# FOXO6... -> CDKN1A
#
# FOXO6... -> CDKN1B
#
# FOXO6... -> RBL2
#
# FOXO6... -> PLK4
#
# FOXO6... -> GADD45G
#
# FOXO6... -> FASLG
#
# FOXO6... -> BCL2L11
#
# FOXO6... -> TNFSF10
#
# FOXO6... -> BCL6
#
# FOXO6... -> BNIP3
#
# FOXO6... -> ATG12
#
# FOXO6... -> GABARAP
#
# FOXO6... -> CAT
#
# FOXO6... -> SOD2
#
# FOXO6... -> GADD45G
#
# FOXO6... -> ATM
#
# FOXO6... -> PCK1
#
# FOXO6... -> G6PC
#
# FOXO6... -> BCL6
#
# FOXO6... -> IL7R
#
# FOXO6... -> KLF2
#
# FOXO6... -> S1PR1
#
# FOXO6... -> RAG1
#
# FOXO6... -> FBXO32
#
# IL6 -> STAT3
#
# IL6 -> STAT3
#
# IL10 -> STAT3
#
# IL10 -> STAT3
#
# STAT3 -> FOXO6...
#
# PRMT1 -> FOXO6...
#
# PRMT1 -> FOXO6...
#
# SETD7 -> FOXO6...
#
# SETD7 -> FOXO6...
#
# GRM1 -> HOMER3
#
# GRM1 -> AGAP2
#
# HOMER3 -> PIK3CA
#
# HOMER3 -> PIK3CA
#
# AGAP2 -> PIK3CA
#
# AGAP2 -> PIK3CA
#
# MAPK1 -> FOXO6...
#
# MAPK1 -> FOXO6...
#
# USP7 -> FOXO6...
#
# ************************************************
# hsa04110: Cell cycle
# ************************************************
# GSK3B -> CCND1
#
# GSK3B -> CCND1
#
# TP53 -> CDKN1A
#
# TP53 -> GADD45G
#
# TP53 -> SFN
#
# GADD45G -> PCNA
#
# MDM2 -> RB1
#
# MDM2 -> TP53
#
# CREBBP -> TP53
#
# PRKDC -> TP53
#
# PRKDC -> TP53
#
# CHEK1 -> TP53
#
# CHEK1 -> TP53
#
# CHEK1 -> CDC25A
#
# CHEK1 -> CDC25A
#
# CDC25A -> CDK4
#
# CDC25A -> CDK4
#
# CDC25A -> CDK2
#
# CDC25A -> CDK2
#
# CDC25A -> CDK2
#
# CDC25A -> CDK2
#
# CDC25A -> CDK1
#
# CDC25A -> CDK1
#
# CHEK1 -> CDC25B...
#
# CHEK1 -> CDC25B...
#
# PTTG2... -> ESPL1
#
# YWHAQ -> CDC25B...
#
# WEE2 -> CDK1
#
# WEE2 -> CDK1
#
# PKMYT1 -> CDK1
#
# PKMYT1 -> CDK1
#
# WEE2 -> CDK1
#
# WEE2 -> CDK1
#
# PKMYT1 -> CDK1
#
# PKMYT1 -> CDK1
#
# PLK1 -> CDC25B...
#
# PLK1 -> CDC25B...
#
# PLK1 -> PKMYT1
#
# PLK1 -> PKMYT1
#
# CDC25B... -> CDK1
#
# CDC25B... -> CDK1
#
# SFN -> CCNB3...
#
# GADD45G -> CCNB3...
#
# CDKN2A -> MDM2
#
# ATM -> TP53
#
# ATM -> TP53
#
# ATM -> CHEK1
#
# ATM -> CHEK1
#
# TTK -> MAD1L1
#
# TTK -> MAD1L1
#
# MAD1L1 -> MAD2L2
#
# BUB1 -> BUB3
#
# MYC -> ZBTB17
#
# ZBTB17 -> CDKN2B
#
# TGFB1 -> SMAD2
#
# TGFB1 -> SMAD2
#
# ABL1 -> RB1
#
# HDAC1 -> RB1
#
# ************************************************
# hsa04114: Oocyte meiosis
# ************************************************
# MOS -> MAP2K1
#
# MOS -> MAP2K1
#
# MAP2K1 -> MAPK1
#
# MAP2K1 -> MAPK1
#
# MAPK1 -> RPS6KA6
#
# MAPK1 -> RPS6KA6
#
# RPS6KA6 -> BUB1
#
# RPS6KA6 -> BUB1
#
# RPS6KA6 -> PKMYT1
#
# RPS6KA6 -> PKMYT1
#
# PKMYT1 -> CDK1
#
# PKMYT1 -> CDK1
#
# BUB1 -> MAD2L2
#
# INS -> IGF1R
#
# IGF1 -> IGF1R
#
# ADCY1 -> PRKACA
#
# PGR -> PRKACA
#
# AR -> PRKACA
#
# IGF1R -> PRKACA
#
# AURKA -> CPEB2
#
# AURKA -> CPEB2
#
# AURKA -> CPEB2
#
# AURKA -> CPEB2
#
# PLK1 -> CPEB2
#
# PLK1 -> CPEB2
#
# CDK2 -> CDC25C
#
# CDK2 -> CDC25C
#
# MAPK12 -> CDC25C
#
# MAPK12 -> CDC25C
#
# PPP1CA -> CDC25C
#
# PPP1CA -> CDC25C
#
# PLK1 -> CDC25C
#
# PLK1 -> CDC25C
#
# SLK -> PLK1
#
# SLK -> PLK1
#
# PRKACA -> CDC25C
#
# PRKACA -> CDC25C
#
# FBXO5 -> CDC20
#
# PTTG2... -> ESPL1
#
# ESPL1 -> REC8
#
# FBXO43 -> CDC20
#
# MAD2L2 -> ANAPC10
#
# MAD2L2 -> ANAPC10
#
# PLCZ1 -> ITPR1
#
# ITPR1 -> CALML6
#
# CALML6 -> PPP3CA
#
# CALML6 -> CAMK2A
#
# PPP2CA -> FBXO43
#
# PPP2CA -> FBXO43
#
# CAMK2A -> FBXO43
#
# CAMK2A -> FBXO43
#
# PLK1 -> FBXO43
#
# PLK1 -> FBXO43
#
# CAMK2A -> CDC25C
#
# CAMK2A -> CDC25C
#
# FBXO43 -> CDC20
#
# BUB1 -> SGO1
#
# PTTG2... -> ESPL1
#
# ESPL1 -> REC8
#
# YWHAQ -> CDC25C
#
# CDC25C -> CDK1
#
# CDC25C -> CDK1
#
# MOS -> PKMYT1
#
# MOS -> PKMYT1
#
# ************************************************
# hsa04115: p53 signaling pathway
# ************************************************
# ATM -> CHEK2
#
# ATM -> CHEK2
#
# ATR -> CHEK1
#
# ATR -> CHEK1
#
# ATR -> TP53
#
# ATR -> TP53
#
# CHEK1 -> TP53
#
# CHEK1 -> TP53
#
# CHEK2 -> TP53
#
# CHEK2 -> TP53
#
# ATM -> TP53
#
# ATM -> TP53
#
# CDKN2A -> MDM2
#
# MDM4 -> MDM2
#
# TP53 -> MDM2
#
# MDM4 -> TP53
#
# IGFBP3 -> IGF1
#
# TP53 -> CDKN1A
#
# TP53 -> SFN
#
# TP53 -> RPRM
#
# TP53 -> GADD45G
#
# TP53 -> GTSE1
#
# TP53 -> FAS
#
# TP53 -> PIDD1
#
# TP53 -> TNFRSF10B
#
# TP53 -> BAX
#
# TP53 -> PMAIP1
#
# BBC3 -> TP53
#
# BBC3 -> TP53AIP1
#
# TP53 -> EI24
#
# TP53 -> SHISA5
#
# TP53 -> PERP
#
# TP53 -> ZMAT3
#
# TP53 -> SIAH1
#
# TP53 -> IGFBP3
#
# TP53 -> SERPINE1
#
# TP53 -> ADGRB1
#
# TP53 -> CD82
#
# TP53 -> THBS1
#
# TP53 -> SERPINB5
#
# TP53 -> DDB2
#
# TP53 -> RRM2B
#
# TP53 -> GADD45G
#
# TP53 -> SESN3
#
# TP53 -> PTEN
#
# TP53 -> TSC2
#
# TP53 -> IGFBP3
#
# TP53 -> STEAP3
#
# TP53 -> MDM2
#
# TP53 -> COP1
#
# TP53 -> RCHY1
#
# TP53 -> CCNG1
#
# TP53 -> SIAH1
#
# TP53 -> PPM1D
#
# TP53 -> TP73
#
# BID -> CYCS
#
# TP53AIP1 -> CYCS
#
# SIAH1 -> CYCS
#
# CYCS -> CASP9
#
# APAF1 -> CASP9
#
# CASP9 -> CASP3
#
# CASP8 -> CASP3
#
# TNFRSF10B -> CASP8
#
# TP53 -> SIVA1
#
# TP53 -> AIFM2
#
# SIVA1 -> BCL2L1
#
# SIVA1 -> BCL2
#
# BCL2L1 -> BAX
#
# BCL2 -> BAX
#
# ************************************************
# hsa04151: PI3K-Akt signaling pathway
# ************************************************
# CSF1 -> CSF1R
#
# CSF1R -> GRB2
#
# GRB2 -> SOS1
#
# SOS1 -> HRAS
#
# HRAS -> RAF1
#
# RAF1 -> MAP2K1
#
# RAF1 -> MAP2K1
#
# MAP2K1 -> MAPK1
#
# MAP2K1 -> MAPK1
#
# MTOR -> RPS6KB1
#
# MTOR -> RPS6KB1
#
# RPS6KB1 -> EIF4B
#
# RPS6KB1 -> EIF4B
#
# RPS6KB1 -> RPS6
#
# RPS6KB1 -> RPS6
#
# C00020 -> PRKAA1
#
# STK11 -> PRKAA1
#
# CSF1R -> IRS1
#
# IRS1 -> PIK3CA
#
# HRAS -> PIK3CA
#
# TLR2 -> RAC1
#
# RAC1 -> PIK3CA
#
# SYK -> CD19
#
# SYK -> CD19
#
# JAK1 -> PIK3CA
#
# PTK2 -> PIK3CA
#
# PIK3CA -> C05981
#
# C05981 -> PDPK1
#
# PDPK1 -> RPS6KB1
#
# PDPK1 -> RPS6KB1
#
# PDPK1 -> PRKCA
#
# PDPK1 -> PRKCA
#
# PDPK1 -> PKN3
#
# PDPK1 -> PKN3
#
# PDPK1 -> C8orf44-SGK3...
#
# PDPK1 -> C8orf44-SGK3...
#
# PIK3R6 -> C05981
#
# C05981 -> AKT3
#
# AKT3 -> NOS3
#
# AKT3 -> NOS3
#
# AKT3 -> CREB3
#
# AKT3 -> CREB3
#
# AKT3 -> CHUK
#
# AKT3 -> CHUK
#
# AKT3 -> MDM2
#
# AKT3 -> MDM2
#
# AKT3 -> RAF1
#
# AKT3 -> RAF1
#
# AKT3 -> GSK3B
#
# AKT3 -> GSK3B
#
# AKT3 -> CDKN1A
#
# AKT3 -> CDKN1A
#
# AKT3 -> CDKN1B
#
# AKT3 -> CDKN1B
#
# AKT3 -> FOXO3
#
# AKT3 -> FOXO3
#
# AKT3 -> BAD
#
# AKT3 -> BAD
#
# AKT3 -> CASP9
#
# AKT3 -> CASP9
#
# GSK3B -> GYS1
#
# GSK3B -> GYS1
#
# GSK3B -> MYC
#
# GSK3B -> MYC
#
# GSK3B -> CCND1
#
# GSK3B -> CCND1
#
# FOXO3 -> CDKN1B
#
# FOXO3 -> RBL2
#
# FOXO3 -> PCK1
#
# FOXO3 -> G6PC
#
# FOXO3 -> FASLG
#
# FOXO3 -> BCL2L11
#
# CREB3 -> BCL2
#
# CREB3 -> MCL1
#
# NFKB1 -> BCL2L1
#
# NFKB1 -> MYB
#
# MDM2 -> TP53
#
# YWHAQ -> FOXO3
#
# YWHAQ -> BAD
#
# BAD -> BCL2L1
#
# BAD -> BCL2
#
# EIF4EBP1 -> EIF4E
#
# CRTC2 -> AKT3
#
# CRTC2 -> AKT3
#
# PDPK1 -> AKT3
#
# PDPK1 -> AKT3
#
# PHLPP2 -> AKT3
#
# PHLPP2 -> AKT3
#
# PPP2R3B -> AKT3
#
# PPP2R3B -> AKT3
#
# PTEN -> C05981
#
# PTEN -> C05981
#
# THEM4 -> AKT3
#
# CHUK -> NFKB1
#
# CHUK -> NFKB1
#
# MTCP1 -> AKT3
#
# NR4A1 -> RXRA
#
# NR4A1 -> BCL2
#
# AKT3 -> NR4A1
#
# AKT3 -> NR4A1
#
# IGH -> SYK
#
# MAGI1 -> PTEN
#
# ************************************************
# hsa04218: Cellular senescence
# ************************************************
# TGFB1 -> TGFBR1
#
# TGFBR1 -> SMAD2
#
# RRAS2 -> PIK3CA
#
# RRAS2 -> RASSF5
#
# RRAS2 -> RAF1
#
# RRAS2 -> C16844...
#
# PIK3CA -> C05981
#
# C05981 -> AKT3
#
# MYC -> CDKN2A
#
# RASSF5 -> HIPK3
#
# C00076 -> CALML6
#
# C00076 -> CAPN1
#
# CAPN1 -> IL1A
#
# CALML6 -> PPP3CA
#
# RHEB -> MTOR
#
# RAF1 -> MAP2K1
#
# RAF1 -> MAP2K1
#
# MAP2K1 -> MAPK1
#
# MAP2K1 -> MAPK1
#
# MAPK1 -> ETS1
#
# MAPK1 -> ETS1
#
# MAP2K3 -> MAPK14
#
# MAP2K3 -> MAPK14
#
# MAPK1 -> MAPK14
#
# MAPK1 -> MAPK14
#
# MAPK14 -> TP53
#
# MAPK14 -> TP53
#
# CHEK2 -> TP53
#
# CHEK2 -> TP53
#
# ATR -> CHEK1
#
# ATR -> CHEK1
#
# CHEK1 -> TP53
#
# CHEK1 -> TP53
#
# MAPK14 -> CDKN2A
#
# MAPK14 -> CDKN2A
#
# AKT3 -> FOXO3
#
# AKT3 -> FOXO3
#
# AKT3 -> TSC1
#
# AKT3 -> TSC1
#
# CHEK1 -> CDC25A
#
# CHEK1 -> CDC25A
#
# MAPKAPK2 -> ZFP36L1
#
# MAPKAPK2 -> ZFP36L1
#
# MTOR -> EIF4EBP1
#
# MTOR -> EIF4EBP1
#
# PTEN -> C05981
#
# SIRT1 -> FOXO3
#
# CDKN2A -> MDM2
#
# RASSF5 -> MDM2
#
# MDM2 -> TP53
#
# TSC1 -> RHEB
#
# RB1 -> E2F1
#
# ATM -> SQSTM1
#
# ATR -> SQSTM1
#
# PPP3CA -> NFATC1
#
# PPP3CA -> NFATC1
#
# PPP1CA -> RB1
# PPP1CA -> RB1
#
# TP53 -> GADD45G
#
# SMAD2 -> CDKN2B
#
# ETS1 -> CDKN2A
#
# TP53 -> CDKN1A
#
# GATA4 -> TRAF3IP2
#
# GATA4 -> IL1A
#
# FOXO3 -> CDKN1A
#
# TP53 -> CDKN1A
#
# E2F1 -> MYBL2
#
# E2F1 -> FOXM1
#
# C07909 -> MTOR
#
# HLA-A -> KIR2DL1
#
# FOXO1 -> SMAD2
#
# CDK4 -> CCND1
#
# CDK2 -> CCNE1
#
# CDK4 -> CCND1
#
# CDK2 -> CCNE1
#
# CDK2 -> CCNA2
#
# CDK1 -> CCNB3...
#
# CDK2 -> CCNE1
#
# CDK4 -> CCND1
#
# MYBL2 -> LIN54
#
# FOXM1 -> LIN54
#
# SLC25A4 -> VDAC1
#
# SLC25A4 -> PPID
#
# MRE11 -> RAD50
#
# RAD50 -> NBN
#
# MRE11 -> NBN
#
# HUS1 -> RAD1
#
# RAD9B... -> RAD1
#
# RAD9B... -> HUS1
#
# TRAF3IP2 -> NFKB1
#
# TRAF3IP2 -> NFKB1
#
# IL1A -> NFKB1
#
# IL1A -> NFKB1
#
# MTOR -> TP53
#
# MTOR -> TP53
#
# PIK3CA -> FOXO1
#
# PIK3CA -> FOXO1
#
# SQSTM1 -> GATA4
#
# RASSF5 -> PPP1CA
#
# SIRT1 -> TP53
#
# RRAS2 -> CDKN2A
#
# C16844... -> MAP2K3
#
# HIPK3 -> TP53
#
# HIPK3 -> TP53
#
# ATM -> CHEK2
#
# ATM -> CHEK2
#
# ************************************************
# hsa04914: Progesterone-mediated oocyte maturation
# ************************************************
# ADCY1 -> PRKACA
#
# PIK3CA -> AKT3
#
# CCNB1 -> CDK1
#
# PGR -> PIK3CA
#
# PGR -> MAPK14
#
# SPDYE2B -> CDK1
#
# SPDYE2B -> CDK2
#
# AURKA -> CPEB2
#
# AURKA -> CPEB2
#
# MOS -> MAP2K1
#
# MOS -> MAP2K1
#
# MAP2K1 -> MAPK1
#
# MAP2K1 -> MAPK1
#
# MAPK1 -> RPS6KA6
#
# MAPK1 -> RPS6KA6
#
# PLK1 -> CDC25A
#
# PLK1 -> CDC25A
#
# RPS6KA6 -> BUB1
#
# RPS6KA6 -> BUB1
#
# KRAS -> ARAF
#
# RPS6KA6 -> PKMYT1
#
# RPS6KA6 -> PKMYT1
#
# PKMYT1 -> CDK1
#
# PKMYT1 -> CDK1
#
# CDC25A -> CDK1
#
# CDC25A -> CDK1
#
# BUB1 -> MAD2L2
#
# FZR1 -> ANAPC10
#
# MAD2L2 -> FZR1
#
# HSP90AA1 -> MOS
#
# GNAI1 -> ADCY1
#
# AKT3 -> PDE3B
#
# AKT3 -> PDE3B
#
# IGF1R -> PIK3CA
#
# IGF1R -> KRAS
#
# INS -> IGF1R
#
# IGF1 -> IGF1R
#
# C00410 -> PGR
#
# ************************************************
# hsa04934: Cushing syndrome
# ************************************************
# AGTR1 -> GNA11
#
# GNA11 -> PLCB1
#
# PLCB1 -> C01245
#
# C01245 -> ITPR1
#
# MC2R -> GNAS
#
# GNAS -> ADCY1
#
# ADCY1 -> C00575
#
# C00575 -> PRKACA
#
# CREB3 -> STAR
#
# CRH -> CRHR1
#
# CRHR1 -> GNAS
#
# GNAS -> ADCY1
#
# ADCY1 -> C00575
#
# C00575 -> PRKACA
#
# PRKACA -> CACNA1C
#
# C00076 -> CAMK2A
#
# CAMK2A -> RAP1A
#
# RAP1A -> BRAF
#
# PRKACA -> RAP1A
#
# PRKACA -> RAP1A
#
# PRKACA -> CREB3
#
# PRKACA -> CREB3
#
# BRAF -> MAP2K1
#
# BRAF -> MAP2K1
#
# MAP2K1 -> MAPK1
#
# MAP2K1 -> MAPK1
#
# MAPK1 -> NR4A1
#
# MAPK1 -> NR4A1
#
# EGFR -> MAPK1
#
# EGFR -> MAPK1
#
# USP8 -> EGFR
#
# CREB3 -> POMC
#
# NR4A1 -> POMC
#
# GNAI1 -> ADCY1
#
# RASD1 -> GNAI1
#
# RB1 -> E2F1
#
# PRKACA -> KCNK2
#
# PRKACA -> NR5A1
#
# PRKACA -> NR4A1
#
# PRKACA -> SP1
#
# PRKACA -> PBX1
#
# PRKACA -> CREB3
#
# NR5A1 -> CYP11B1
#
# NR5A1 -> CYP17A1
#
# NR5A1 -> STAR
#
# NR5A1 -> NCEH1
#
# NR4A1 -> CYP11B1
#
# NR4A1 -> CYP17A1
#
# NR4A1 -> STAR
#
# NR4A1 -> NCEH1
#
# SP1 -> CYP11B1
#
# SP1 -> CYP17A1
#
# SP1 -> STAR
#
# SP1 -> NCEH1
#
# PBX1 -> CYP11B1
#
# PBX1 -> CYP17A1
#
# PBX1 -> STAR
#
# PBX1 -> NCEH1
#
# CREB3 -> CYP11B1
#
# CREB3 -> CYP17A1
#
# CREB3 -> NCEH1
#
# WNT16... -> FZD10
#
# FZD10 -> DVL1
#
# DVL1 -> GSK3B
#
# C00076 -> KCNK2
#
# AGT -> AGTR1
#
# ************************************************
# hsa05160: Hepatitis C
# ************************************************
# DDX58 -> MAVS
#
# TLR3 -> TICAM1
#
# TICAM1 -> TRAF3
#
# EIF2AK1 -> IFIT1
#
# EIF2AK1 -> EIF2S1
#
# EGF -> EGFR
#
# SOS1 -> HRAS
#
# HRAS -> ARAF
#
# ARAF -> MAP2K1
#
# PIK3CA -> C05981
#
# TNF -> TNFRSF1A
#
# TRADD -> TRAF2
#
# TRADD -> FADD
#
# CHUK -> NFKBIA
#
# FASLG -> FAS
#
# FAS -> FADD
#
# FADD -> CASP8
#
# CASP8 -> BID
#
# BID -> BAX
#
# BID -> BAK1
#
# BAX -> CYCS
#
# BAK1 -> CYCS
#
# CYCS -> CASP9
#
# CASP9 -> CASP3
#
# CDK2 -> RB1
#
# MAVS -> CHUK
#
# MAVS -> CHUK
#
# TRAF2 -> CHUK
#
# TRAF2 -> CHUK
#
# SOCS3 -> STAT1
#
# PIAS1 -> STAT1
#
# YWHAQ -> ARAF
#
# GSK3B -> CTNNB1
#
# CFLAR -> CASP8
#
# CDKN1A -> CDK2
#
# PPP2CA -> STAT1
#
# PPP2CA -> STAT1
#
# RB1 -> E2F1
#
# NFKB1 -> NFKBIA
#
# NFKB1 -> NFKBIA
#
# IRF3 -> IFNA1
#
# IRF3 -> IFNG
#
# IRF3 -> TNF
#
# IRF3 -> CXCL10
#
# NFKB1 -> TNF
#
# NFKB1 -> CXCL10
#
# IRF9 -> OAS1
#
# IRF9 -> EIF2AK1
#
# IRF9 -> IFIT1
#
# IRF9 -> IRF7
#
# IRF9 -> MX1
#
# IRF9 -> RSAD2
#
# STAT1 -> IRF9
#
# TP53 -> CDKN1A
#
# IFIT1 -> EIF3E
#
# EGFR -> GRB2
#
# GRB2 -> SOS1
#
# TNFRSF1A -> TRADD
#
# APAF1 -> CASP9
#
# CASP8 -> CASP3
#
# CHUK -> NFKBIA
#
# CHUK -> NFKBIA
#
# EIF2AK1 -> CHUK
#
# EIF2AK1 -> CHUK
#
# C05981 -> AKT3
#
# C05981 -> AKT3
#
# AKT3 -> GSK3B
#
# AKT3 -> GSK3B
#
# AKT3 -> BAD
#
# AKT3 -> BAD
#
# AKT3 -> CDKN1A
#
# AKT3 -> CDKN1A
#
# MAP2K1 -> MAPK1
#
# MAP2K1 -> MAPK1
#
# JAK1 -> STAT1
#
# JAK1 -> STAT1
#
# MAVS -> TRAF3
#
# C20935 -> OAS1
#
# C20935 -> RNASEL
#
# ************************************************
# hsa05161: Hepatitis B
# ************************************************
# CHUK -> NFKBIA
#
# FASLG -> FAS
#
# FAS -> FADD
#
# CASP12 -> CASP3
#
# APAF1 -> CASP9
#
# CASP9 -> CASP3
#
# PTK2B -> SRC
#
# SRC -> GRB2
#
# HRAS -> ARAF
#
# PRKCA -> ARAF
#
# ARAF -> MAP2K1
#
# ARAF -> MAP2K1
#
# MAP2K1 -> MAPK1
#
# MAP2K1 -> MAPK1
#
# MAPK8 -> JUN
#
# MAPK8 -> SMAD4
#
# HRAS -> MAP3K1
#
# IRAK4 -> TLR4
#
# IRAK4 -> TRAF6
#
# TRAF6 -> TAB1
#
# MAPK14 -> JUN
#
# MAPK8 -> SRC
#
# TLR3 -> TICAM1
#
# TICAM2 -> TICAM1
#
# TLR4 -> TICAM2
#
# DDX58 -> MAVS
#
# IFIH1 -> MAVS
#
# TGFBR1 -> SMAD2
#
# TGFBR1 -> SMAD2
#
# MAPK8 -> SMAD2
#
# MAPK8 -> SMAD2
#
# AKT3 -> CHUK
#
# AKT3 -> CHUK
#
# JAK1 -> STAT1
#
# JAK1 -> STAT1
#
# JAK1 -> STAT3
#
# JAK1 -> STAT3
#
# MAP3K7 -> CHUK
#
# MAP3K7 -> CHUK
#
# CHUK -> NFKBIA
#
# CHUK -> NFKBIA
#
# MAP3K7 -> MAP2K1
#
# MAP3K7 -> MAP2K1
#
# MAP2K1 -> MAPK1
#
# MAP2K1 -> MAPK1
#
# MAP2K1 -> MAPK14
#
# MAP2K1 -> MAPK14
#
# MAP2K1 -> MAPK8
#
# MAP2K1 -> MAPK8
#
# MAP3K7 -> MAP2K3
#
# MAP3K7 -> MAP2K3
#
# MAP3K7 -> MAP2K7
#
# MAP3K7 -> MAP2K7
#
# MAP2K3 -> MAPK14
#
# MAP2K3 -> MAPK14
#
# MAPK8 -> JUN
#
# MAPK8 -> JUN
#
# PIK3CA -> AKT3
#
# PIK3CA -> AKT3
#
# PIK3CA -> AKT3
#
# MAPK1 -> CREB3
#
# MAPK1 -> CREB3
#
# MAPK1 -> CREB3
#
# NFKB1 -> NFKB1
#
# BIRC5 -> CASP9
#
# BIRC5 -> CASP3
#
# SMAD2 -> CDKN1A
#
# SMAD2 -> MYC
#
# EGR2 -> FASLG
#
# NFKB1 -> MMP9
#
# NFKB1 -> BCL2
#
# TP53 -> BAX
#
# TP53 -> FAS
#
# TP53 -> CDKN1A
#
# FOS -> MMP9
#
# NFKB1 -> TNF
#
# NFKB1 -> IL6
#
# IRF3 -> IFNA1
#
# IRF3 -> IFNB1
#
# NFKB1 -> NFKBIA
#
# NFKBIA -> NFKB1
#
# AKT3 -> BAD
#
# AKT3 -> BAD
#
# CCNE1 -> RB1
#
# RB1 -> E2F1
#
# NFATC1 -> TNF
#
# BCL2 -> BAX
#
# IFNA1 -> IFNAR1
#
# TICAM1 -> TRAF3
#
# MAVS -> TRAF3
#
# TRAF3 -> TBK1
#
# EGR2 -> CREBBP
#
# APAF1 -> CYCS
#
# SMAD2 -> SMAD2
#
# SMAD2 -> SMAD2
#
# ATP6AP1 -> PRKCA
#
# GRB2 -> SOS1
#
# SOS1 -> HRAS
#
# C00076 -> PTK2B
#
# ************************************************
# hsa05162: Measles
# ************************************************
# SLAMF1 -> SH2D1A
#
# SH2D1A -> FYN
#
# FYN -> SLAMF1
#
# FYN -> SLAMF1
#
# SLAMF1 -> DOK1
#
# DOK1 -> PRKCQ
#
# DOK1 -> PRKCQ
#
# CD3D -> PIK3CA
#
# CD3D -> PIK3CA
#
# CD28 -> PIK3CA
#
# CD28 -> PIK3CA
#
# IL2RA -> PIK3CA
#
# IL2RA -> PIK3CA
#
# PIK3CA -> AKT3
#
# PIK3CA -> AKT3
#
# AKT3 -> GSK3B
#
# AKT3 -> GSK3B
#
# IL2 -> IL2RA
#
# IL2 -> IL2RA
#
# IL2RA -> JAK1
#
# JAK1 -> STAT3
#
# JAK1 -> STAT3
#
# DDX58 -> MAVS
#
# IFIH1 -> MAVS
#
# CHUK -> IRF7
#
# CHUK -> IRF7
#
# TLR7 -> MYD88
#
# MYD88 -> IRAK1
#
# IRAK1 -> IRF7
#
# IRAK1 -> IRF7
#
# MAVS -> IRF7
#
# MAVS -> IRF7
#
# MAVS -> NFKB1
#
# MAVS -> NFKB1
#
# TLR2 -> MYD88
#
# MYD88 -> IRAK1
#
# IRAK1 -> TRAF6
#
# NFKBIA -> NFKB1
#
# FCGR2B -> IL12A
#
# FCGR2B -> IL12A
#
# IFNA1 -> IFNAR1
#
# IFNAR1 -> RACK1
#
# RACK1 -> STAT1
#
# IFNAR1 -> JAK1
#
# JAK1 -> STAT1
#
# JAK1 -> STAT1
#
# STAT1 -> IRF9
#
# IFNG -> IFNGR1
#
# IFNGR1 -> JAK1
#
# JAK1 -> STAT1
#
# JAK1 -> STAT1
#
# STAT1 -> IRF9
#
# CCND1 -> CDKN1B
#
# FASLG -> FAS
#
# TNFSF10 -> TNFRSF10B
#
# EIF2AK1 -> EIF2S1
#
# EIF2AK1 -> EIF2S1
#
# RCHY1 -> TP53
#
# RCHY1 -> TP53
#
# CBLB -> PIK3CA
#
# CBLB -> PIK3CA
#
# TNFAIP3 -> TRAF6
#
# PRKCQ -> IL13
#
# PRKCQ -> IL4
#
# IRF3 -> IFNA1
#
# IRF3 -> IFNB1
#
# IRF7 -> IFNA1
#
# IRF7 -> IFNB1
#
# NFKB1 -> IFNA1
#
# NFKB1 -> IFNB1
#
# IRF9 -> OAS1
#
# IRF9 -> ADAR
#
# IRF9 -> MX1
#
# TP73 -> BBC3
#
# ************************************************
# hsa05165: Human papillomavirus infection
# ************************************************
# WNT16... -> FZD10
#
# FZD10 -> DVL1
#
# UBE3A -> CTNNB1
#
# TLR3 -> TICAM1
#
# TICAM1 -> TRAF3
#
# PTK2 -> PXN
#
# TNF -> TNFRSF1A
#
# TRADD -> FADD
#
# FASLG -> FAS
#
# FAS -> FADD
#
# FADD -> CASP8
#
# CASP8 -> CASP3
#
# PDGFRB -> PIK3CA
#
# PIK3CA -> C05981
#
# C05981 -> AKT3
#
# PDGFRB -> GRB2
#
# EGF -> EGFR
#
# EGFR -> GRB2
#
# GRB2 -> SOS1
#
# SOS1 -> HRAS
#
# HRAS -> RAF1
#
# C00584 -> PTGER4
#
# PTGER4 -> GNAS
#
# C00575 -> PRKACA
#
# PRKACA -> CREB3
#
# JAG1 -> NOTCH1
#
# DVL1 -> GSK3B
#
# CREBBP -> TP53
#
# TADA3 -> TP53
#
# PTEN -> C05981
#
# PPP2R3B -> AKT3
#
# RHEB -> MTOR
#
# MTOR -> RPS6KB1
#
# MTOR -> RPS6KB1
#
# MTOR -> EIF4EBP1
#
# MTOR -> EIF4EBP1
#
# UBE3A -> TP53
#
# RB1 -> E2F1
#
# AKT3 -> FOXO1
#
# MDM2 -> TP53
#
# TCIRG1 -> EGFR
#
# IRF3 -> IFNB1
#
# FOXO1 -> CDKN1B
#
# FOXO1 -> CDKN1A
#
# TP53 -> CDKN1B
#
# TP53 -> CDKN1A
#
# IRF1 -> IFNB1
#
# CREB3 -> PTGER4
#
# EGFR -> PTGS2
#
# LFNG -> NOTCH1
#
# E2F1 -> CCNA2
#
# E2F1 -> CCNE1
#
# PRKACA -> BAX
#
# PRKACA -> BAX
#
# AKT3 -> BAD
#
# AKT3 -> BAD
#
# AKT3 -> GSK3B
#
# AKT3 -> GSK3B
#
# GSK3B -> CCND1
#
# GSK3B -> CCND1
#
# AKT3 -> CHUK
#
# AKT3 -> CHUK
#
# AKT3 -> MDM2
#
# AKT3 -> MDM2
#
# CHUK -> NFKB1
#
# CHUK -> NFKB1
#
# EGFR -> PIK3CA
#
# EGFR -> PIK3CA
# GNAS -> C00575
#
# GNAS -> C00575
#
# CTNNB1 -> TERT
#
# TERT -> TCF7
#
# AKT3 -> VEGFA
#
# AKT3 -> VEGFA
#
# RAF1 -> MAP2K1
#
# RAF1 -> MAP2K1
#
# MAP2K1 -> MAPK1
#
# MAP2K1 -> MAPK1
#
# PTGS2 -> C00584
#
# STAT1 -> STAT2
#
# STAT2 -> STAT1
#
# PSMC1 -> RB1
#
# UBE3A -> NFX1
#
# NFX1 -> TERT
#
# ************************************************
# hsa05166: Human T-cell leukemia virus 1 infection
# ************************************************
# ITGAL -> ICAM1
#
# ICAM1 -> ITGAL
#
# B2M -> HLA-A
#
# ICAM1 -> HRAS
#
# HRAS -> MAP2K1
#
# MAP2K1 -> MAPK1
#
# IL2RB -> JAK1
#
# PIK3CA -> C05981
#
# C05981 -> AKT3
#
# DLG1 -> PTEN
#
# IKBKG -> CHUK
#
# CHUK -> NFKB2
#
# ADCY1 -> C00575
#
# C00575 -> PRKACA
#
# AKT3 -> JUN
#
# AKT3 -> JUN
#
# TNFRSF1A -> MAP3K1
#
# TNFRSF1A -> MAP3K1
#
# TNFRSF1A -> MAP3K3
#
# TNFRSF1A -> MAP3K3
#
# IL1R1 -> MAP3K3
#
# IL1R1 -> MAP3K3
#
# CD3D -> MAP3K3
#
# CD3D -> MAP3K3
#
# LTBR -> MAP3K14
#
# LTBR -> MAP3K14
#
# CD40 -> MAP3K14
#
# CD40 -> MAP3K14
#
# TNFRSF13C -> MAP3K14
#
# TNFRSF13C -> MAP3K14
#
# TGFB1 -> TGFBR1
#
# MYC -> CCND2
#
# NFATC1 -> IL2
#
# STAT5A -> IL2
#
# NFYB -> HLA-DMA
#
# CREB3 -> CCND1
#
# TCF3 -> POLB
#
# TCF3 -> LCK
#
# TCF3 -> BAX
#
# TCF3 -> CDKN2C
#
# MYC -> TERT
#
# FDPS -> HRAS
#
# FDPS -> HRAS
#
# PTTG2... -> ESPL1
#
# MAP3K1 -> MAP2K4
#
# MAP3K1 -> MAP2K4
#
# MAP2K4 -> MAPK8
#
# MAP2K4 -> MAPK8
#
# MAPK8 -> JUN
#
# MAPK8 -> JUN
#
# MAP3K14 -> CHUK
#
# MAP3K14 -> CHUK
#
# TGFBR1 -> SMAD2
#
# TGFBR1 -> SMAD2
#
# PRKACA -> CREB3
#
# PRKACA -> CREB3
#
# RB1 -> E2F1
#
# CALR -> C00076
#
# CALR -> C00076
#
# CANX -> C00076
#
# CANX -> C00076
#
# C00076 -> PPP3CA
#
# PPP3CA -> NFATC1
#
# PPP3CA -> NFATC1
#
# JAK1 -> STAT5A
#
# JAK1 -> STAT5A
#
# ATM -> CHEK1
#
# ATM -> CHEK1
#
# CHEK1 -> TP53
#
# CHEK1 -> TP53
#
# ANAPC10 -> PTTG2...
#
# ANAPC10 -> PTTG2...
#
# ANAPC10 -> CCNB2
#
# ANAPC10 -> CCNB2
#
# MAD2L1 -> CDC20
#
# BUB1B -> JUN
#
# JUN -> MMP7
#
# NFKB1 -> IL2
#
# NFKB1 -> IL2RA
#
# NFKB1 -> IL15
#
# NFKB1 -> IL15RA
#
# NFKB1 -> IL6
#
# NFKB1 -> CSF2
#
# NFKB1 -> LTA
#
# NFKB1 -> BCL2L1
#
# NFKB1 -> XIAP
#
# NFKB2 -> IL2
#
# NFKB2 -> IL2RA
#
# NFKB2 -> IL15
#
# NFKB2 -> IL15RA
#
# NFKB2 -> IL6
#
# NFKB2 -> CSF2
#
# NFKB2 -> LTA
#
# NFKB2 -> BCL2L1
#
# NFKB2 -> XIAP
#
# TNF -> TNFRSF1A
#
# TP53 -> CDKN1A
#
# PTEN -> C05981
#
# NFKBIA -> NFKB1
#
# ************************************************
# hsa05169: Epstein-Barr virus infection
# ************************************************
# HLA-A -> B2M
#
# TLR2 -> MYD88
#
# MYD88 -> IRAK1
#
# IRAK1 -> TAB1
#
# DDX58 -> MAVS
#
# MAVS -> TRAF3
#
# FAS -> FADD
#
# EIF2AK2 -> FADD
#
# FADD -> CASP8
#
# CASP8 -> CASP3
#
# CASP8 -> BID
#
# BID -> BAK1
#
# CYCS -> APAF1
#
# APAF1 -> CASP9
#
# CASP9 -> CASP3
#
# IFNA1 -> IFNAR1
#
# IFNAR1 -> JAK1
#
# IFNAR1 -> TYK2
#
# PIK3CA -> C05981
#
# C05981 -> AKT3
#
# LYN -> PIK3CA
#
# SYK -> PIK3CA
#
# PIK3CA -> C05981
#
# C05981 -> AKT3
#
# PIK3CA -> RAC1
#
# IGH -> LYN
#
# IGH -> SYK
#
# PLCG2 -> C01245
#
# MDM2 -> TP53
#
# MDM2 -> TP53
#
# SKP2 -> CDKN1B
#
# SKP2 -> CDKN1B
#
# NEDD4 -> LYN
#
# NEDD4 -> LYN
#
# NEDD4 -> SYK
#
# NEDD4 -> SYK
#
# USP7 -> TP53
#
# SKP2 -> RB1
#
# SKP2 -> RB1
#
# CHUK -> NFKBIA
#
# CHUK -> NFKBIA
#
# MAP3K14 -> CHUK
#
# MAP3K14 -> CHUK
#
# CHUK -> NFKB2
#
# CHUK -> NFKB2
#
# MAP3K7 -> CHUK
#
# MAP3K7 -> CHUK
#
# CHUK -> NFKBIA
#
# CHUK -> NFKBIA
#
# MAP3K7 -> MAP2K7
#
# MAP3K7 -> MAP2K7
#
# MAP2K7 -> MAPK8
#
# MAP2K7 -> MAPK8
#
# MAP2K3 -> MAPK14
#
# MAP2K3 -> MAPK14
#
# MAPK8 -> JUN
#
# MAPK8 -> JUN
#
# MAPK14 -> JUN
#
# MAPK14 -> JUN
#
# RB1 -> E2F1
#
# NFKB1 -> NFKBIA
#
# BAK1 -> CYCS
#
# BAK1 -> CYCS
#
# NFKB1 -> TNF
#
# NFKB1 -> IL6
#
# IRF7 -> IFNA1
#
# IRF7 -> IFNB1
#
# IRF3 -> IFNA1
#
# IRF3 -> IFNB1
#
# RBPJL -> CR2
#
# RBPJL -> HES1
#
# RBPJL -> FCER2
#
# RBPJL -> RUNX3
#
# RBPJL -> MYC
#
# TP53 -> CDKN1A
#
# TP53 -> GADD45G
#
# TP53 -> BAX
#
# TP53 -> BAK1
#
# TP53 -> DDB2
#
# TP53 -> POLK
#
# NFKB2 -> FCER2
#
# NFKB2 -> ENTPD8
#
# NFKB2 -> CD40
#
# NFKB2 -> CD44
#
# NFKB2 -> ITGAL
#
# NFKB2 -> CD58
#
# NFKB2 -> ICAM1
#
# NFKB2 -> VIM
#
# NFKB1 -> FCER2
#
# NFKB1 -> ENTPD8
#
# NFKB1 -> CD40
#
# NFKB1 -> CD44
#
# NFKB1 -> ITGAL
#
# NFKB1 -> CD58
#
# NFKB1 -> ICAM1
#
# NFKB1 -> VIM
#
# JUN -> FCER2
#
# JUN -> ENTPD8
#
# JUN -> CD40
#
# JUN -> CD44
#
# JUN -> ITGAL
#
# JUN -> CD58
#
# JUN -> ICAM1
#
# JUN -> VIM
#
# JUN -> TNFAIP3
#
# JUN -> BCL2
#
# NFKB2 -> TNFAIP3
#
# NFKB2 -> BCL2
#
# NFKB1 -> TNFAIP3
#
# NFKB1 -> BCL2
#
# TRAF3 -> PIK3CA
#
# TRAF3 -> PIK3CA
#
# TRAF3 -> MAP3K14
#
# TRAF3 -> MAP3K14
#
# TRADD -> MAP3K14
#
# TRADD -> MAP3K14
#
# LYN -> LYN
#
# LYN -> LYN
#
# SYK -> SYK
#
# SYK -> SYK
#
# ************************************************
# hsa05200: Pathways in cancer
# ************************************************
# CASP3 -> DCC
#
# PTK2 -> PIK3CA
#
# ABL1 -> STAT5A
#
# ABL1 -> GRB2
#
# TGFA -> EGFR
#
# PDGFA -> PDGFRA
#
# IGF1 -> IGF1R
#
# HGF -> MET
#
# EGFR -> PIK3CA
#
# EGFR -> JAK1
#
# ERBB2 -> PIK3CA
#
# ERBB2 -> JAK1
#
# EGFR -> PLCG1
#
# PDGFRA -> PLCG1
#
# PDGFRA -> GRB2
#
# PDGFRA -> PIK3CA
#
# IGF1R -> PLCG1
#
# IGF1R -> GRB2
#
# IGF1R -> PIK3CA
#
# KIT -> PIK3CA
#
# KIT -> GRB2
#
# FLT3 -> PIK3CA
#
# FLT3 -> GRB2
#
# MET -> GRB2
#
# FGFR1 -> GRB2
#
# GRB2 -> SOS1
#
# SOS1 -> HRAS
#
# HRAS -> ARAF
#
# HRAS -> PIK3CA
#
# HRAS -> RASSF1
#
# PRKCA -> ARAF
#
# HRAS -> RALGDS
#
# RALGDS -> RALA
#
# RALA -> RALBP1
#
# RALA -> PLD1
#
# RALGDS -> RHOA
#
# FASLG -> FAS
#
# FAS -> FADD
#
# FADD -> CASP8
#
# CASP8 -> BID
#
# CYCS -> CASP9
#
# DVL1 -> GSK3B
#
# PML -> SPI1
#
# RUNX1 -> SPI1
#
# RUNX1 -> CEBPA
#
# MDM2 -> TP53
#
# SHH -> PTCH1
#
# PTCH1 -> SMO
#
# AKT3 -> GSK3B
#
# AKT3 -> GSK3B
#
# AKT3 -> CASP9
#
# AKT3 -> CASP9
#
# AKT3 -> BAD
#
# AKT3 -> BAD
#
# AKT3 -> FOXO1
#
# AKT3 -> FOXO1
#
# AKT3 -> CDKN1B
#
# AKT3 -> CDKN1B
#
# AKT3 -> CDKN1A
#
# AKT3 -> CDKN1A
#
# AKT3 -> CHUK
#
# AKT3 -> CHUK
#
# CHUK -> NFKBIA
#
# CHUK -> NFKBIA
#
# AKT3 -> MTOR
#
# AKT3 -> MTOR
#
# AKT3 -> MDM2
#
# AKT3 -> MDM2
#
# JAK1 -> STAT3
#
# JAK1 -> STAT3
#
# JAK1 -> STAT1
#
# JAK1 -> STAT1
#
# ARAF -> MAP2K1
#
# ARAF -> MAP2K1
#
# MAP2K1 -> MAPK1
#
# MAP2K1 -> MAPK1
#
# MAPK1 -> JUN
#
# MAPK1 -> JUN
#
# MAPK1 -> FOS
#
# MAPK1 -> FOS
#
# MAPK1 -> MYC
#
# MAPK1 -> MYC
#
# RET -> HRAS
#
# TFG -> HRAS
#
# PRKCA -> HRAS
#
# MDM2 -> TP53
#
# BAD -> BCL2L1
#
# RALBP1 -> RAC1
#
# AR -> KLK3
#
# LEF1 -> BIRC5
#
# LEF1 -> MYC
#
# LEF1 -> CCND1
#
# NFKB1 -> PTGS2
#
# NFKB1 -> NOS2
#
# NFKB1 -> BCL2
#
# NFKB1 -> BIRC8
#
# NFKB1 -> BCL2L1
#
# NFKB1 -> TRAF1
#
# NFKB1 -> CCND1
#
# STAT5A -> BCL2L1
#
# STAT3 -> VEGFD
#
# STAT1 -> VEGFD
#
# JUN -> VEGFD
#
# JUN -> CXCL8
#
# JUN -> MMP1
#
# JUN -> CCND1
#
# JUN -> CDK4
#
# FOS -> VEGFD
#
# FOS -> CXCL8
#
# FOS -> MMP1
#
# FOS -> CCND1
#
# FOS -> CDK4
#
# MYC -> VEGFD
#
# MYC -> CXCL8
#
# MYC -> MMP1
#
# MYC -> CCND1
#
# MYC -> CDK4
#
# JUP -> PPARD
#
# JUP -> MYC
#
# JUP -> CCND1
#
# ZBTB17 -> CDKN2B
#
# EPAS1 -> SLC2A1
#
# EPAS1 -> VEGFD
#
# EPAS1 -> PDGFB
#
# EPAS1 -> TGFB1
#
# EPAS1 -> TGFA
#
# GLI1 -> BMP2
#
# GLI1 -> GLI1
#
# GLI1 -> WNT16...
#
# GLI1 -> HHIP
#
# GLI1 -> PTCH1
#
# NFKBIA -> NFKB1
#
# JUP -> LEF1
#
# SMAD2 -> SMAD4
#
# EPAS1 -> ARNT
#
# EPAS1 -> CREBBP
#
# RARA -> JUP
#
# PML -> JUP
#
# RUNX1 -> JUP
#
# C05981 -> AKT3
#
# C00165 -> PRKCA
#
# C00076 -> PRKCA
#
# RB1 -> E2F1
#
# RHOA -> MAPK8
#
# PPARG -> RXRA
#
# GSK3B -> CTNNB1
#
# NKX3-1 -> AKT3
#
# RASSF1 -> STK4
#
# RASSF1 -> CCND1
#
# RASSF1 -> HRAS
#
# DAPK1 -> MAPK1
#
# SPI1 -> CSF3R
#
# SPI1 -> CSF2RA
#
# SPI1 -> CSF1R
#
# CEBPA -> CSF3R
#
# CEBPA -> IL6
#
# CEBPA -> E2F1
#
# CEBPA -> MYC
#
# CEBPA -> CSF3R
#
# CEBPA -> IL6
#
# CEBPA -> E2F1
#
# CEBPA -> MYC
#
# RUNX1 -> CSF1R
#
# TP53 -> CDKN1A
#
# CDKN2A -> MDM2
#
# EGLN2 -> EPAS1
#
# RARA -> CCNA1
#
# PML -> CCNA1
#
# KITLG -> KIT
#
# FLT3LG -> FLT3
#
# FGF1 -> FGFR1
#
# RASSF5 -> RASSF1
#
# ETS1 -> VEGFD
#
# ETS1 -> MMP1
#
# ETS1 -> CXCL8
#
# ETS1 -> CCND1
#
# ETS1 -> CDK4
#
# BID -> CYCS
#
# C00535 -> AR
#
# C03917 -> AR
#
# C00951... -> AR
#
# C00187 -> SHH
#
# C00122 -> EGLN2
#
# RUNX1 -> CSF1R
#
# PLD1 -> C00416
#
# PTEN -> C05981
#
# EGF -> EGFR
#
# PIK3CA -> C05981
#
# CTNNB1 -> LEF1
#
# MAPK1 -> ETS1
#
# MAPK1 -> ETS1
#
# PLCG1 -> C00165
#
# PLCG1 -> C00076
#
# SMO -> SUFU
#
# SUFU -> GLI1
#
# KIF7 -> SUFU
#
# JAG1 -> NOTCH1
#
# DLL3 -> NOTCH1
#
# NOTCH1 -> ERBB2
#
# NOTCH1 -> HES1
#
# NOTCH1 -> HEY1
#
# NOTCH1 -> FLT4
#
# C00122 -> C00149
#
# C01471 -> KEAP1
#
# C00704 -> KEAP1
#
# C21641 -> KEAP1
#
# C21642 -> KEAP1
#
# C00027 -> KEAP1
#
# C16844 -> KEAP1
#
# C00533 -> KEAP1
#
# KEAP1 -> NFE2L2
#
# NFE2L2 -> HMOX1
#
# NFE2L2 -> NQO1
#
# NFE2L2 -> GSTO2
#
# NFE2L2 -> TXNRD2
#
# TP53 -> GADD45G
#
# TP53 -> BAK1
#
# TP53 -> POLK
#
# TP53 -> BAX
#
# TP53 -> DDB2
#
# FRAT1... -> DVL1
#
# EDNRA -> GNA11
#
# GNA11 -> PLCB1
#
# PLCB1 -> C01245
#
# PLCB1 -> C00165
#
# C00165 -> PRKCA
#
# C00165 -> RASGRP1
#
# PLCB1 -> C00076
#
# C00076 -> RASGRP1
#
# RASGRP1 -> HRAS
#
# C00951 -> ESR1
#
# MAPK1 -> RPS6KA5
#
# MAPK1 -> RPS6KA5
#
# RPS6KA5 -> MYC
#
# PMAIP1 -> BCL2
#
# BBC3 -> BCL2
#
# BAD -> BCL2
#
# BCL2L11 -> BCL2
#
# BCL2 -> BAX
#
# BAX -> CYCS
#
# CYCS -> APAF1
#
# CASP9 -> CASP3
#
# STAT5A -> PIM2...
#
# JAK1 -> STAT5A
#
# JAK1 -> STAT5A
#
# JAK1 -> STAT2
#
# JAK1 -> STAT2
#
# MTOR -> RPS6KB1
#
# MTOR -> RPS6KB1
#
# EPO -> CSF2RB
#
# CSF2RB -> JAK1
#
# ALK -> JAK1
#
# ALK -> PIK3CA
#
# ALK -> HRAS
#
# ALK -> HRAS
#
# PRKCA -> ELK1
#
# C00076 -> CALML6
#
# CALML6 -> CAMK2A
#
# CAMK2A -> HRAS
#
# CAMK2A -> HRAS
#
# BCL2L1 -> BAX
#
# BCL2L1 -> BAK1
#
# BAK1 -> CYCS
#
# ALK -> PLCG1
#
# F2 -> EDNRA
#
# KNG1 -> EDNRA
#
# EDN1 -> EDNRA
#
# AGT -> EDNRA
#
# F2 -> LPAR6
#
# F2 -> CXCR4
# AGT -> LPAR6
#
# AGT -> CXCR4
#
# C00681 -> LPAR6
#
# C00681 -> CXCR4
#
# CXCL12 -> CXCR4
#
# C00584 -> PTGER1
#
# ************************************************
# hsa05203: Viral carcinogenesis
# ************************************************
# MDM2 -> TP53
#
# CREBBP -> TP53
#
# PSMC1 -> RB1
#
# ************************************************
# hsa05215: Prostate cancer
# ************************************************
# PIK3CA -> PDPK1
#
# PIK3CA -> PDPK1
#
# PIK3CA -> AKT3
#
# PIK3CA -> AKT3
#
# EGF -> EGFR
#
# EGFR -> PIK3CA
#
# EGFR -> GRB2
#
# GRB2 -> SOS1
#
# SOS1 -> HRAS
#
# HRAS -> ARAF
#
# ARAF -> MAP2K1
#
# ARAF -> MAP2K1
#
# MAP2K1 -> MAPK1
#
# MAP2K1 -> MAPK1
#
# PDPK1 -> AKT3
#
# PDPK1 -> AKT3
#
# AKT3 -> MDM2
#
# AKT3 -> MDM2
#
# AKT3 -> CHUK
#
# AKT3 -> CHUK
#
# AKT3 -> MTOR
#
# AKT3 -> MTOR
#
# AKT3 -> CASP9
#
# AKT3 -> CASP9
#
# AKT3 -> BAD
#
# AKT3 -> BAD
#
# AKT3 -> FOXO1
#
# AKT3 -> FOXO1
#
# AKT3 -> CDKN1A
#
# AKT3 -> CDKN1A
#
# AKT3 -> CDKN1B
#
# AKT3 -> CDKN1B
#
# AKT3 -> GSK3B
#
# AKT3 -> GSK3B
#
# GSK3B -> CREB3
#
# GSK3B -> CREB3
#
# GSK3B -> CTNNB1
#
# GSK3B -> CTNNB1
#
# CHUK -> NFKBIA
#
# CHUK -> NFKBIA
#
# E2F1 -> RB1
#
# MDM2 -> TP53
#
# CREB3 -> CREBBP
#
# CTNNB1 -> CREBBP
#
# NFKB1 -> NFKBIA
#
# CTNNB1 -> LEF1
#
# LEF1 -> CCND1
#
# NFKB1 -> BCL2
#
# GSTP1 -> C16038
#
# CREBBP -> TP53
#
# NKX3-1 -> AKT3
#
# PTEN -> C05981
#
# ************************************************
# hsa05222: Small cell lung cancer
# ************************************************
# PIK3CA -> AKT3
#
# CKS1B -> SKP2
#
# PTK2 -> PIK3CA
#
# AKT3 -> CHUK
#
# AKT3 -> CHUK
#
# CHUK -> NFKBIA
#
# CHUK -> NFKBIA
#
# ZBTB17 -> CDKN2B
#
# NFKB1 -> CCND1
#
# NFKB1 -> BIRC8
#
# NFKB1 -> BCL2L1
#
# NFKB1 -> TRAF1
#
# NFKB1 -> PTGS2
#
# NFKB1 -> NOS2
#
# SKP2 -> CDKN1B
#
# E2F1 -> RB1
#
# NFKBIA -> NFKB1
#
# CYCS -> CASP9
#
# APAF1 -> CASP9
#
# PTEN -> C05981
#
# BCL2 -> BAX
#
# CASP9 -> CASP3
#
# TP53 -> CDKN1A
#
# TP53 -> GADD45G
#
# TP53 -> BAX
#
# TP53 -> BAK1
#
# TP53 -> DDB2
#
# TP53 -> POLK
#
# ************************************************
# hsa05226: Gastric cancer
# ************************************************
# SHC2 -> GRB2
#
# GRB2 -> SOS1
#
# SOS1 -> HRAS
#
# HRAS -> ARAF
#
# ARAF -> MAP2K1
#
# ARAF -> MAP2K1
#
# MAP2K1 -> MAPK1
#
# MAP2K1 -> MAPK1
#
# PIK3CA -> C05981
#
# C05981 -> AKT3
#
# AKT3 -> MTOR
#
# AKT3 -> MTOR
#
# MTOR -> RPS6KB1
#
# TP53 -> CDKN1A
#
# TP53 -> GADD45G
#
# TP53 -> BAX
#
# TP53 -> BAK1
#
# TP53 -> DDB2
#
# TP53 -> POLK
#
# SMAD2 -> SMAD4
#
# FZD10 -> DVL1
#
# DVL1 -> FRAT1...
#
# DVL1 -> GSK3B
#
# CTNNB1 -> LEF1
#
# LEF1 -> MYC
#
# LEF1 -> CCND1
#
# HGF -> MET
#
# MET -> GRB2
#
# GRB2 -> SOS1
#
# SOS1 -> HRAS
#
# HRAS -> ARAF
#
# ARAF -> MAP2K1
#
# ARAF -> MAP2K1
#
# MAP2K1 -> MAPK1
#
# MAP2K1 -> MAPK1
#
# MET -> GAB1
#
# GAB1 -> PIK3CA
#
# PIK3CA -> C05981
#
# C05981 -> AKT3
#
# AKT3 -> MTOR
#
# AKT3 -> MTOR
#
# AKT3 -> TP53
#
# AKT3 -> TP53
#
# TP53 -> BCL2
#
# FGF1 -> FGFR2
#
# FGFR2 -> GRB2
#
# FGFR2 -> GAB1
#
# AKT3 -> GSK3B
#
# CDH1 -> CTNNA1
#
# CDH1 -> JUP
#
# CDH1 -> CTNNB1
#
# CDH1 -> CTNNB1
#
# CTNNB1 -> LEF1
#
# LEF1 -> MYC
#
# LEF1 -> CCND1
#
# TP53 -> CDKN1A
#
# TP53 -> CDKN1A
#
# TP53 -> GADD45G
#
# TP53 -> GADD45G
#
# TP53 -> BAX
#
# TP53 -> BAX
#
# TP53 -> BAK1
#
# TP53 -> BAK1
#
# TP53 -> DDB2
#
# TP53 -> DDB2
#
# TP53 -> POLK
#
# TP53 -> POLK
#
# CDX2 -> MUC2
#
# CDX2 -> CDH17
#
# CDX2 -> REG4
#
# CDX2 -> ABCB1
#
# CDX2 -> SHH
#
# RB1 -> E2F1
#
# SMAD2 -> CDKN2B
#
# SMAD2 -> CDKN2B
#
# SMAD2 -> CDKN1A
#
# SMAD2 -> CDKN1A

# %%
#Load the conversion table between affymetrix and common gene names
pathways = pd.read_csv('pathways.txt', delimiter='\t')

# %%
pathways
# Out:
#           id pathway_id                                       pathway_name
# 0          0   hsa03030                                    DNA replication
# 1          1   hsa03420                         Nucleotide excision repair
# 2          2   hsa03430                                    Mismatch repair
# 3          3   hsa03040                                        Spliceosome
# 4          4   hsa04010                             MAPK signaling pathway
# 5          5   hsa04141        Protein processing in endoplasmic reticulum
# 6          6   hsa04144                                        Endocytosis
# 7          7   hsa04213    Longevity regulating pathway - multiple species
# 8          8   hsa04612                Antigen processing and presentation
# 9          9   hsa04915                         Estrogen signaling pathway
# 10        10   hsa05134                                      Legionellosis
# 11        11   hsa05145                                      Toxoplasmosis
# 12        12   hsa05162                                            Measles
# 13        13   hsa05164                                        Influenza A
# 14        14   hsa04918                          Thyroid hormone synthesis
# 15        15   hsa05200                                 Pathways in cancer
# 16        16   hsa05202            Transcriptional misregulation in cancer
# 17        17   hsa05216                                     Thyroid cancer
# 18        18   hsa04744                                  Phototransduction
# 19        19   hsa04080            Neuroactive ligand-receptor interaction
# 20        20   hsa04919                  Thyroid hormone signaling pathway
# 21        21   hsa04060             Cytokine-cytokine receptor interaction
# 22        22   hsa04062                        Chemokine signaling pathway
# 23        23   hsa04620               Toll-like receptor signaling pathway
# 24        24   hsa04621                NOD-like receptor signaling pathway
# 25        25   hsa04623                      Cytosolic DNA-sensing pathway
# 26        26   hsa04668                              TNF signaling pathway
# 27        27   hsa05020                                     Prion diseases
# 28        28   hsa05120  Epithelial cell signaling in Helicobacter pylo...
# 29        29   hsa05142          Chagas disease (American trypanosomiasis)
# ...      ...        ...                                                ...
# 48439  48439   hsa05170           Human immunodeficiency virus 1 infection
# 48440  48440   hsa04120                     Ubiquitin mediated proteolysis
# 48441  48441   hsa04141        Protein processing in endoplasmic reticulum
# 48442  48442   hsa03460                             Fanconi anemia pathway
# 48443  48443   hsa00511                           Other glycan degradation
# 48444  48444   hsa04137                                 Mitophagy - animal
# 48445  48445   hsa00510                              N-Glycan biosynthesis
# 48446  48446   hsa01100                                 Metabolic pathways
# 48447  48447   hsa04141        Protein processing in endoplasmic reticulum
# 48448  48448   hsa04150                             mTOR signaling pathway
# 48449  48449   hsa04310                              Wnt signaling pathway
# 48450  48450   hsa04390                            Hippo signaling pathway
# 48451  48451   hsa04550  Signaling pathways regulating pluripotency of ...
# 48452  48452   hsa04916                                      Melanogenesis
# 48453  48453   hsa04934                                   Cushing syndrome
# 48454  48454   hsa05165                     Human papillomavirus infection
# 48455  48455   hsa05200                                 Pathways in cancer
# 48456  48456   hsa05205                            Proteoglycans in cancer
# 48457  48457   hsa05217                               Basal cell carcinoma
# 48458  48458   hsa05224                                      Breast cancer
# 48459  48459   hsa05225                           Hepatocellular carcinoma
# 48460  48460   hsa05226                                     Gastric cancer
# 48461  48461   hsa05168                   Herpes simplex virus 1 infection
# 48462  48462   hsa04060             Cytokine-cytokine receptor interaction
# 48463  48463   hsa04062                        Chemokine signaling pathway
# 48464  48464   hsa04668                              TNF signaling pathway
# 48465  48465   hsa05163                    Human cytomegalovirus infection
# 48466  48466   hsa00650                               Butanoate metabolism
# 48467  48467   hsa01100                                 Metabolic pathways
# 48468  48468   hsa03018                                    RNA degradation
#
# [48469 rows x 3 columns]

# %%
#For all the distinct pathways find all the genes that build a given pathway. 
#Create a file with a list of all the interrelations between the genes in a given pathway.
pfsnet_file = open("pfsnet_pathways.txt","w+")
pfsnet_file.write("pathway\tgene1\tgene2\n")
for ind in pathways:
    network = k.parse_kgml_pathway(ind)
    entries = pd.DataFrame.from_dict(network['entries'])
    for item in network['relations']:
        gene1 = entries[entries['id']==item['entry1']]
        gene2 = entries[entries['id']==item['entry2']]
        if gene1['gene_names'].values != None and gene2['gene_names'].values != None:
            gene1 = gene1['gene_names'].values[0].split(','[0])[0]
            gene2 = gene2['gene_names'].values[0].split(','[0])[0]
            pfsnet_file.write(str(pathway[ind]) +"\t"+ str(gene1)+"\t"+ str(gene2) + "\n")
pfsnet_file.close()

# %% [markdown]
# ### Relapse/non-relapse data split

# %%
relapse = pd.DataFrame()
non_relapse = pd.DataFrame()
relapse['ID'] = conversion_table['gene_name']
non_relapse['ID'] = conversion_table['gene_name']
for index in relapse_dataset[relapse_dataset['relapse (1=True)'] == 1].index:
    patient_id = relapse_dataset.iloc[index]['asscession number']
    relapse[patient_id] = dataset[patient_id]

for index in relapse_dataset[relapse_dataset['relapse (1=True)'] == 0].index:
    patient_id = relapse_dataset.iloc[index]['asscession number']
    non_relapse[patient_id] = dataset[patient_id]

# %%
relapse = relapse.drop(relapse[relapse['ID'] == '-'].index)

columns = relapse.columns[1:]
temp_array=[]

unique_gene_id = relapse['ID'].unique()
for gene_id in unique_gene_id:
    temp_dataframe = relapse[relapse['ID']==gene_id]
    row_entry = [gene_id]
    for column in columns:
        row_entry.append(temp_dataframe[column].max())
    temp_array.append(row_entry)
    
relapse_cleaned = pd.DataFrame(temp_array, columns = relapse.columns)  
relapse_cleaned.to_csv("pfsnet_relapse_cleaned.txt", sep='\t')

# %%
relapse_cleaned = pd.read_csv('relapse_cleaned.txt', delimiter='\t')
relapse_cleaned
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-7630badac249> in <module>()
# ----> 1 relapse_cleaned = pd.read_csv('relapse_cleaned.txt', delimiter='\t')
#       2 relapse_cleaned
#
# c:\users\pawel\appdata\local\programs\python\python36\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# c:\users\pawel\appdata\local\programs\python\python36\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# c:\users\pawel\appdata\local\programs\python\python36\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# c:\users\pawel\appdata\local\programs\python\python36\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# c:\users\pawel\appdata\local\programs\python\python36\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'relapse_cleaned.txt' does not exist

# %%
non_relapse = non_relapse.drop(non_relapse[non_relapse['ID'] == '-'].index)

columns = non_relapse.columns[1:]
temp_array=[]

unique_gene_id = non_relapse['ID'].unique()
for gene_id in unique_gene_id:
    temp_dataframe = non_relapse[non_relapse['ID']==gene_id]
    row_entry = [gene_id]
    for column in columns:
        row_entry.append(temp_dataframe[column].max())
    temp_array.append(row_entry)
    
non_relapse_cleaned = pd.DataFrame(temp_array, columns = non_relapse.columns)  
non_relapse_cleaned.to_csv("pfsnet_non_relapse_cleaned.txt", sep='\t')

# %%
non_relapse_cleaned = pd.read_csv('non_relapse_cleaned.txt', delimiter='\t')
non_relapse_cleaned

# %%
pfsnet_pathways_cleaned = pd.read_csv('pfsnet_pathways_cleaned.txt', delimiter='\t')
pfsnet_pathways_cleaned
# Out:
#        Unnamed: 0   pathway                   gene1  \
# 0               0  hsa04010                   GNA12
# 1               1  hsa04010                 RAPGEF2
# 2               2  hsa04010                 RASGRF1
# 3               3  hsa04010                 RASGRP1
# 4               4  hsa04010                   RAP1A
# 5               5  hsa04010                     TNF
# 6               6  hsa04010                    IL1A
# 7               7  hsa04010                   FASLG
# 8               8  hsa04010                   TGFB1
# 9               9  hsa04010                     FAS
# 10             10  hsa04010                  TGFBR1
# 11             11  hsa04010                    GRB2
# 12             12  hsa04010                    SOS1
# 13             13  hsa04010                    TAB2
# 14             14  hsa04010                   ECSIT
# 15             15  hsa04010                     SRF
# 16             16  hsa04010                     SRF
# 17             17  hsa04010                 LAMTOR3
# 18             18  hsa04010                 LAMTOR3
# 19             19  hsa04010                   MAPK1
# 20             20  hsa04010                MAPK8IP2
# 21             21  hsa04010                MAPK8IP2
# 22             22  hsa04010                MAPK8IP2
# 23             23  hsa04010                MAPK8IP2
# 24             24  hsa04010                   MAPK8
# 25             25  hsa04010                  MAP2K4
# 26             26  hsa04010                  MAP2K7
# 27             27  hsa04010                MAPK8IP3
# 28             28  hsa04010                 MAP3K11
# 29             29  hsa04010                   MAPK8
# ...           ...       ...                     ...
# 14104       18600  hsa00430                    CDO1
# 14105       18601  hsa00430                    CDO1
# 14106       18602  hsa00430  Glutathione metabolism
# 14107       18603  hsa00430                    CDO1
# 14108       18604  hsa00430                    GAD1
# 14109       18605  hsa00430                   GADL1
# 14110       18607  hsa00430                    CSAD
# 14111       18608  hsa00780                    HLCS
# 14112       18612  hsa00780                    HLCS
# 14113       18624  hsa00780                    HLCS
# 14114       18628  hsa00780                     BTD
# 14115       18629  hsa00780                     BTD
# 14116       18630  hsa00780      Lysine degradation
# 14117       18631  hsa00440                   PCYT2
# 14118       18632  hsa00440                  PCYT1A
# 14119       18633  hsa05033                  C00334
# 14120       18634  hsa05033                  C01996
# 14121       18635  hsa05033                  C01996
# 14122       18636  hsa05033                  C00025
# 14123       18637  hsa05033                  C00025
# 14124       18639  hsa05033                  C01996
# 14125       18641  hsa05033                  C00745
# 14126       18647  hsa05033                  C00745
# 14127       18648  hsa05033                  C00745
# 14128       18650  hsa00785                    LIAS
# 14129       18653  hsa00785                   LIPT2
# 14130       18654  hsa00785                   LIPT2
# 14131       18655  hsa00785                    LIAS
# 14132       18656  hsa00785                    LIAS
# 14133       18657  hsa00785                   LIPT2
#
#                                     gene2
# 0                                   RASA2
# 1                                   RRAS2
# 2                                   RRAS2
# 3                                   RRAS2
# 4                                    BRAF
# 5                                TNFRSF1A
# 6                                   IL1R1
# 7                                     FAS
# 8                                  TGFBR1
# 9                                    DAXX
# 10                                   DAXX
# 11                                  CSF1R
# 12                                   GRB2
# 13                                  TRAF6
# 14                                  TRAF6
# 15                                   ELK1
# 16                                   ELK4
# 17                                 MAP2K1
# 18                                 MAP2K2
# 19                                LAMTOR3
# 20                                  MAPK8
# 21                                 MAP2K7
# 22                                MAP3K11
# 23                                 MAP4K1
# 24                               MAPK8IP3
# 25                               MAPK8IP3
# 26                               MAPK8IP3
# 27                                 MAP3K1
# 28                               MAPK8IP3
# 29                                    CRK
# ...                                   ...
# 14104              Glutathione metabolism
# 14105          Cyanoamino acid metabolism
# 14106          Cyanoamino acid metabolism
# 14107  Cysteine and methionine metabolism
# 14108  Cysteine and methionine metabolism
# 14109  Cysteine and methionine metabolism
# 14110  Cysteine and methionine metabolism
# 14111                                 BTD
# 14112                                HLCS
# 14113             Fatty acid biosynthesis
# 14114                  Lysine degradation
# 14115                             Tropane
# 14116                             Tropane
# 14117                            CEPT1...
# 14118                            CEPT1...
# 14119                           GABRR3...
# 14120                              CHRNA4
# 14121                              CHRNA7
# 14122                              GRIN3A
# 14123                               GRIA1
# 14124                              CHRNA6
# 14125                              CHRNA7
# 14126                              CHRNA6
# 14127                              CHRNA4
# 14128                               LIPT2
# 14129                                LIAS
# 14130                               LIPT1
# 14131                               LIPT1
# 14132             Fatty acid biosynthesis
# 14133             Fatty acid biosynthesis
#
# [14134 rows x 4 columns]

# %%
genes_list = conversion_table.drop_duplicates(['gene_name'])['gene_name']
genes_list.values
# Out:
# array(['DDR1', 'RFC2', 'HSPA6', ..., 'FAM86B1', 'SNHG17', 'LOC100505915'],
#       dtype=object)

# %%
gene_list = pd.concat([pfsnet_pathways_cleaned['gene1'], pfsnet_pathways_cleaned['gene2']])
gene_list = pd.DataFrame(gene_list, columns=['gene_name'])
gene_list = gene_list.drop_duplicates(['gene_name'])
count = 0
for gene in gene_list['gene_name']:
    if gene in genes_list.values:
        count = count + 1
    else:
        
        
print(count)
print(gene_list.size)
print(genes_list.size)
# Out:
# 2511
# 3362
# 12938

# %% [markdown]
# ## 2. PFSNet score generation

# %% [markdown]
# ## 3. Classification model prediction
